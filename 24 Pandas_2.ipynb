# %%
import pandas as pd

# %%
df =pd.read_csv("sales_data_final.csv")

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.sample(10)
# Out:
#               order_id  order_date   ship_date       ship_mode  customer_name  \
# 6216    MX-2011-121790  10/15/2011  10/20/2011  Standard Class  Greg Matthias
# 40886    ID-2014-10076    7/9/2014   7/13/2014  Standard Class  Hunter Glantz
# 2747   ES-2011-2399281    6/8/2011   6/11/2011     First Class    Angele Hood
# 50504   CA-2014-164000  12/19/2014  12/23/2014  Standard Class  Aaron Hawkins
# 29514    ID-2013-42906   10/2/2013   10/4/2013    Second Class   Dario Medina
# 3330      TU-2011-9570   6/28/2011    7/4/2011  Standard Class    Sean Miller
# 43746   CA-2014-137582    9/5/2014    9/9/2014  Standard Class  Cynthia Voltz
# 30519   MX-2013-115350  10/31/2013   11/5/2013  Standard Class   Art Ferguson
# 51232  ES-2014-3458802  12/31/2014    1/5/2015  Standard Class     John Grady
# 13961     EG-2012-3730    8/2/2012    8/4/2012    Second Class   Ralph Arnett
#
#            segment           state         country  market          region  \
# ...

# %%
df[df['profit'] == max(df['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df[df["profit"]==max(df['profit'])][["customer_name","region", "profit"]]
# Out:
#       customer_name   region    profit
# 29530  Tamara Chand  Central  8399.976

# %%
df[df["profit"]==min(df["profit"])]["customer_name"]
# Out:
# 31884    Cindy Stewart
# Name: customer_name, dtype: object

# %%
df[df['profit'] == max(df['profit'])][['segment','customer_name',"region"]]
# Out:
#          segment customer_name   region
# 29530  Corporate  Tamara Chand  Central

# %%
len(df[df['country'] == 'Sweden'])
# Out:
# 203

# %%
len(df[df["country"]== "Mexico"])
# Out:
# 2644

# %%
df[df['shipping_cost'] > 80]['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df[df["shipping_cost"]>80][['country', "ship_mode" ]]
# Out:
#            country       ship_mode
# 7        Australia        Same Day
# 8      New Zealand  Standard Class
# 9             Iraq  Standard Class
# 27          Brazil    Second Class
# 43          Mexico  Standard Class
# ...            ...             ...
# 51154    Indonesia    Second Class
# 51228       Brazil    Second Class
# 51229    Indonesia     First Class
# 51230       Russia    Second Class
# 51231     Thailand     First Class
#
# [3984 rows x 2 columns]

# %%
df[df["shipping_cost"]>40][['country', "ship_mode" ]]
# Out:
#            country       ship_mode
# 7        Australia        Same Day
# 8      New Zealand  Standard Class
# 9             Iraq  Standard Class
# 27          Brazil    Second Class
# 28          Mexico  Standard Class
# ...            ...             ...
# 51235       Brazil    Second Class
# 51236        Spain    Second Class
# 51237        India    Second Class
# 51238    Nicaragua        Same Day
# 51239  Philippines  Standard Class
#
# [8437 rows x 2 columns]

# %%
df[df["shipping_cost"]<40][['country', "ship_mode", "region" ]]
# Out:
#              country       ship_mode   region
# 0            Algeria  Standard Class   Africa
# 1          Australia  Standard Class  Oceania
# 2            Hungary    Second Class     EMEA
# 3             Sweden    Second Class    North
# 4          Australia  Standard Class  Oceania
# ...              ...             ...      ...
# 51285  United States  Standard Class     West
# 51286        Morocco  Standard Class   Africa
# 51287      Nicaragua    Second Class  Central
# 51288         Mexico  Standard Class    North
# 51289  United States  Standard Class     West
#
# [42852 rows x 3 columns]

# %%
df[(df['shipping_cost'] > 100 ) & (df['profit'] < 10 )]["country"]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df[(df['shipping_cost'] > 100 ) and (df['profit'] < 10 )]["country"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14992\4011179618.py in ?()
# ----> 1 df[(df['shipping_cost'] > 100 ) and (df['profit'] < 10 )]["country"]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[['profit','customer_name', 'region']].max()
# Out:
# profit                     8399.976
# customer_name    Zuschuss Donatelli
# region                         West
# dtype: object

# %%
df[['profit','customer_name', 'region']].min()
# Out:
# profit               -6599.978
# customer_name    Aaron Bergman
# region                  Africa
# dtype: object

# %%
df["profit"].max()
# Out:
# 8399.976

# %%
df["region"].max()
# Out:
# 'West'

# %%
df.order_date
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
date =pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df.sample()
# Out:
#             order_id order_date  ship_date    ship_mode customer_name  \
# 3829  MX-2011-157595  7/27/2011  7/28/2011  First Class     Liz Preis
#
#        segment      state    country market   region  ... sub_category  \
# 3829  Consumer  Guatemala  Guatemala  LATAM  Central  ...      Binders
#
#                              product_name sales quantity discount  profit  \
# 3829  Ibico Hole Reinforcements, Recycled    29        6      0.0    6.96
#
#       shipping_cost  order_priority  year converted_order_date
# 3829           4.88            High  2011           2011-07-27
#
# [1 rows x 22 columns]

# %%
df['order_date_year'] = df['converted_order_date'].dt.year

# %%
df.sample()
# Out:
#             order_id order_date  ship_date ship_mode     customer_name  \
# 26212  IN-2013-56388  7/26/2013  7/26/2013  Same Day  Richard Eichhorn
#
#         segment       state    country market   region  ...  \
# 26212  Consumer  Queensland  Australia   APAC  Oceania  ...
#
#                    product_name sales quantity discount  profit  \
# 26212  StarTech Calculator, Red   134        4      0.1  48.876
#
#        shipping_cost  order_priority  year  converted_order_date  \
# 26212          17.77          Medium  2013            2013-07-26
#
#       order_date_year
# 26212            2013
#
# [1 rows x 23 columns]

# %%
df['order_date_month'] = df['converted_order_date'].dt.month

# %%
df['order_date_week'] = df['converted_order_date'].dt.isocalendar().week

# %%
df.sample()
# Out:
#            order_id order_date  ship_date       ship_mode customer_name  \
# 42224  GG-2014-4090  8/11/2014  8/16/2014  Standard Class  Sarah Jordon
#
#         segment    state  country market region  ... quantity discount profit  \
# 42224  Consumer  Imereti  Georgia   EMEA   EMEA  ...        6      0.0   14.4
#
#       shipping_cost order_priority  year  converted_order_date  \
# 42224          6.15         Medium  2014            2014-08-11
#
#        order_date_year  order_date_month order_date_week
# 42224             2014                 8              33
#
# [1 rows x 25 columns]

# %%
df['order_date_day'] = df['converted_order_date'].dt.day

# %%
df.sample()
# Out:
#            order_id  order_date   ship_date       ship_mode  customer_name  \
# 32819  NI-2013-2520  12/12/2013  12/18/2013  Standard Class  Patrick Jones
#
#          segment        state  country  market  region  ... discount profit  \
# 32819  Corporate  Cross River  Nigeria  Africa  Africa  ...      0.7 -67.83
#
#       shipping_cost order_priority  year  converted_order_date  \
# 32819          2.51         Medium  2013            2013-12-12
#
#        order_date_year  order_date_month  order_date_week order_date_day
# 32819             2013                12               50             12
#
# [1 rows x 26 columns]

# %%
df[df['order_date_year'] == 2014 ]["customer_name"]
# Out:
# 33759         Fred Harton
# 33760         Kean Nguyen
# 33761        Alan Shonely
# 33762        Duane Benoit
# 33763       Kelly Lampkin
#                ...
# 51285          Erica Bern
# 51286           Liz Preis
# 51287    Charlotte Melton
# 51288       Tamara Dahlen
# 51289       Jill Matthias
# Name: customer_name, Length: 17531, dtype: object

# %%
df[df["order_date_year"] == 2014]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
df['order_date_month'].value_counts()
# Out:
# order_date_month
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: count, dtype: int64

# %%
df["order_date_year"].value_counts()
# Out:
# order_date_year
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States    9994
# Australia        2837
# France           2827
# Mexico           2644
# Germany          2065
#                  ...
# Burundi             2
# Chad                2
# Eritrea             2
# Bahrain             2
# South Sudan         2
# Name: count, Length: 147, dtype: int64

# %%
df['cost_to_comapny'] = df['discount'] + df['shipping_cost']

# %%
df.sample()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_name  \
# 6310  RO-2011-9820  10/19/2011  10/23/2011  Standard Class   Dean percer
#
#           segment state  country market region  ... profit shipping_cost  \
# 6310  Home Office  Dolj  Romania   EMEA   EMEA  ...  39.36          9.71
#
#      order_priority  year converted_order_date  order_date_year  \
# 6310         Medium  2011           2011-10-19             2011
#
#       order_date_month  order_date_week  order_date_day cost_to_comapny
# 6310                10               42              19            9.71
#
# [1 rows x 27 columns]

# %% [markdown]
# ### LOC & ILOC

# %%
df[1:10, "segment"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(1, 10, None), 'segment')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df[1:10, "segment"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
# ...

# %%
df.loc[[2,9,11]]
# Out:
#          order_id order_date ship_date       ship_mode     customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 9    IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
# 11  IN-2011-65159   1/3/2011  1/7/2011    Second Class      Larry Blacks
#
#       segment             state      country market          region  ...  \
# 2    Consumer          Budapest      Hungary   EMEA            EMEA  ...
# 9   Corporate            Ninawa         Iraq   EMEA            EMEA  ...
# 11   Consumer  National Capital  Philippines   APAC  Southeast Asia  ...
#
#       profit shipping_cost order_priority  year converted_order_date  \
# 2    29.6400          8.17           High  2011           2011-01-01
# 9   253.3200         81.26           High  2011           2011-01-03
# 11  -70.3995         21.32           High  2011           2011-01-03
#
#     order_date_year  order_date_month  order_date_week  order_date_day  \
# ...

# %%
df.loc[[2,5,9, 11, 51000]]
# Out:
#             order_id  order_date   ship_date       ship_mode  \
# 2       HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 5      IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 9       IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 11     IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 51000  IN-2014-32812  12/27/2014  12/31/2014  Standard Class
#
#           customer_name    segment             state          country market  \
# 2         Annie Thurman   Consumer          Budapest          Hungary   EMEA
# 5           Joseph Holt   Consumer   New South Wales        Australia   APAC
# 9      Lindsay Williams  Corporate            Ninawa             Iraq   EMEA
# 11         Larry Blacks   Consumer  National Capital      Philippines   APAC
# 51000        Corey-Lock   Consumer            Yangon  Myanmar (Burma)   APAC
#
#                region  ...    profit shipping_cost order_priority  year  \
# ...

# %%
df.loc[2:10:3]
# Out:
#         order_id order_date ship_date       ship_mode  customer_name  \
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class  Annie Thurman
# 5  IN-2011-47883   1/1/2011  1/8/2011  Standard Class    Joseph Holt
# 8  ID-2011-80230   1/3/2011  1/9/2011  Standard Class   Ken Lonsdale
#
#     segment            state      country market   region  ...   profit  \
# 2  Consumer         Budapest      Hungary   EMEA     EMEA  ...   29.640
# 5  Consumer  New South Wales    Australia   APAC  Oceania  ...   15.342
# 8  Consumer         Auckland  New Zealand   APAC  Oceania  ... -319.464
#
#   shipping_cost order_priority  year converted_order_date  order_date_year  \
# 2          8.17           High  2011           2011-01-01             2011
# 5          1.80         Medium  2011           2011-01-01             2011
# 8        107.10            Low  2011           2011-01-03             2011
#
#    order_date_month  order_date_week  order_date_day cost_to_comapny
# ...

# %%
df.loc[0:1,['order_id']]
# Out:
#         order_id
# 0   AG-2011-2040
# 1  IN-2011-47883

# %%
df.loc[0:10:2,['order_id','order_date','ship_date']]
# Out:
#          order_id order_date ship_date
# 0    AG-2011-2040   1/1/2011  1/6/2011
# 2    HU-2011-1220   1/1/2011  1/5/2011
# 4   IN-2011-47883   1/1/2011  1/8/2011
# 6    CA-2011-1510   1/2/2011  1/6/2011
# 8   ID-2011-80230   1/3/2011  1/9/2011
# 10  IN-2011-65159   1/3/2011  1/7/2011

# %%
df.iloc[0:10]
# Out:
#           order_id order_date ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class   Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7    IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8    ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...   profit  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...  106.140
# ...

# %%
df.iloc[0:9:2,2:10:2]
# Out:
#   ship_date    customer_name            state  market
# 0  1/6/2011  Toby Braunhardt      Constantine  Africa
# 2  1/5/2011    Annie Thurman         Budapest    EMEA
# 4  1/8/2011      Joseph Holt  New South Wales    APAC
# 6  1/6/2011  Magdelene Morse          Ontario  Canada
# 8  1/9/2011     Ken Lonsdale         Auckland    APAC

# %%
df2= df[df.dtypes[(df.dtypes == 'float64') | ( df.dtypes == 'int64')].index]

# %%
df2 =df[df.dtypes[(df.dtypes == 'float64') | ( df.dtypes == 'int64')].index]

# %%
df2
# Out:
#        quantity  discount    profit  shipping_cost  year  cost_to_comapny
# 0             2       0.0  106.1400          35.46  2011            35.46
# 1             3       0.1   36.0360           9.72  2011             9.82
# 2             4       0.0   29.6400           8.17  2011             8.17
# 3             3       0.5  -26.0550           4.82  2011             5.32
# 4             5       0.1   37.7700           4.70  2011             4.80
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             1.09
# 51286         1       0.0    0.4200           0.49  2014             0.49
# 51287         3       0.0   12.3600           0.35  2014             0.35
# 51288         1       0.0    0.5600           0.20  2014             0.20
# 51289         3       0.2   -0.6048           0.17  2014             0.37
#
# [51290 rows x 6 columns]

# %%
df2.dtypes
# Out:
# quantity             int64
# discount           float64
# profit             float64
# shipping_cost      float64
# year                 int64
# cost_to_comapny    float64
# dtype: object

# %%
df2[df2 > 100]
# Out:
#        quantity  discount  profit  shipping_cost  year  cost_to_comapny
# 0           NaN       NaN  106.14            NaN  2011              NaN
# 1           NaN       NaN     NaN            NaN  2011              NaN
# 2           NaN       NaN     NaN            NaN  2011              NaN
# 3           NaN       NaN     NaN            NaN  2011              NaN
# 4           NaN       NaN     NaN            NaN  2011              NaN
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014              NaN
# 51286       NaN       NaN     NaN            NaN  2014              NaN
# 51287       NaN       NaN     NaN            NaN  2014              NaN
# 51288       NaN       NaN     NaN            NaN  2014              NaN
# 51289       NaN       NaN     NaN            NaN  2014              NaN
#
# [51290 rows x 6 columns]

# %%
df2[df2 > 10]
# Out:
#        quantity  discount   profit  shipping_cost  year  cost_to_comapny
# 0           NaN       NaN  106.140          35.46  2011            35.46
# 1           NaN       NaN   36.036            NaN  2011              NaN
# 2           NaN       NaN   29.640            NaN  2011              NaN
# 3           NaN       NaN      NaN            NaN  2011              NaN
# 4           NaN       NaN   37.770            NaN  2011              NaN
# ...         ...       ...      ...            ...   ...              ...
# 51285       NaN       NaN      NaN            NaN  2014              NaN
# 51286       NaN       NaN      NaN            NaN  2014              NaN
# 51287       NaN       NaN   12.360            NaN  2014              NaN
# 51288       NaN       NaN      NaN            NaN  2014              NaN
# 51289       NaN       NaN      NaN            NaN  2014              NaN
#
# [51290 rows x 6 columns]

# %%
df3 = df2[df2>100]

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  cost_to_comapny
# 0           NaN       NaN  106.14            NaN  2011              NaN
# 1           NaN       NaN     NaN            NaN  2011              NaN
# 2           NaN       NaN     NaN            NaN  2011              NaN
# 3           NaN       NaN     NaN            NaN  2011              NaN
# 4           NaN       NaN     NaN            NaN  2011              NaN
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014              NaN
# 51286       NaN       NaN     NaN            NaN  2014              NaN
# 51287       NaN       NaN     NaN            NaN  2014              NaN
# 51288       NaN       NaN     NaN            NaN  2014              NaN
# 51289       NaN       NaN     NaN            NaN  2014              NaN
#
# [51290 rows x 6 columns]

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, cost_to_comapny]
# Index: []

# %%
df3.dropna(axis=1)
# Out:
#        year
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
# ...     ...
# 51285  2014
# 51286  2014
# 51287  2014
# 51288  2014
# 51289  2014
#
# [51290 rows x 1 columns]

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  cost_to_comapny
# 0           NaN       NaN  106.14            NaN  2011              NaN
# 1           NaN       NaN     NaN            NaN  2011              NaN
# 2           NaN       NaN     NaN            NaN  2011              NaN
# 3           NaN       NaN     NaN            NaN  2011              NaN
# 4           NaN       NaN     NaN            NaN  2011              NaN
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014              NaN
# 51286       NaN       NaN     NaN            NaN  2014              NaN
# 51287       NaN       NaN     NaN            NaN  2014              NaN
# 51288       NaN       NaN     NaN            NaN  2014              NaN
# 51289       NaN       NaN     NaN            NaN  2014              NaN
#
# [51290 rows x 6 columns]

# %%
df3.dropna(thresh=2)
# Out:
#        quantity  discount   profit  shipping_cost  year  cost_to_comapny
# 0           NaN       NaN  106.140            NaN  2011              NaN
# 7           NaN       NaN  110.412         125.32  2011           125.42
# 8           NaN       NaN      NaN         107.10  2011           107.50
# 9           NaN       NaN  253.320            NaN  2011              NaN
# 12          NaN       NaN  290.430            NaN  2011              NaN
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014              NaN
# 51236       NaN       NaN  180.240            NaN  2014              NaN
# 51245       NaN       NaN  105.000            NaN  2014              NaN
# 51252       NaN       NaN  166.440            NaN  2014              NaN
# 51269       NaN       NaN  153.090            NaN  2014              NaN
#
# [6823 rows x 6 columns]

# %%
df3.fillna(value=4)
# Out:
#        quantity  discount  profit  shipping_cost  year  cost_to_comapny
# 0           4.0       4.0  106.14            4.0  2011              4.0
# 1           4.0       4.0    4.00            4.0  2011              4.0
# 2           4.0       4.0    4.00            4.0  2011              4.0
# 3           4.0       4.0    4.00            4.0  2011              4.0
# 4           4.0       4.0    4.00            4.0  2011              4.0
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014              4.0
# 51286       4.0       4.0    4.00            4.0  2014              4.0
# 51287       4.0       4.0    4.00            4.0  2014              4.0
# 51288       4.0       4.0    4.00            4.0  2014              4.0
# 51289       4.0       4.0    4.00            4.0  2014              4.0
#
# [51290 rows x 6 columns]

# %%
df3.fillna(value=df3['profit'].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 1      285.710477  285.710477  285.710477     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        cost_to_comapny
# 0           285.710477
# 1           285.710477
# 2           285.710477
# 3           285.710477
# 4           285.710477
# ...                ...
# 51285       285.710477
# ...

# %%
df3['quantity'].mean()
# Out:
# nan

# %% [markdown]
# ### Groupby

# %%
df.groupby('order_date_year')["profit"].min()
# Out:
# order_date_year
# 2011   -3701.8928
# 2012   -2639.9912
# 2013   -6599.9780
# 2014   -3839.9904
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')["profit"].max()
# Out:
# order_date_year
# 2011    4630.4755
# 2012    3177.4750
# 2013    8399.9760
# 2014    6719.9808
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')['profit'].mean()
# Out:
# order_date_year
# 2011    27.666238
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')["quantity"].max()
# Out:
# order_date_year
# 2011    14
# 2012    14
# 2013    14
# 2014    14
# Name: quantity, dtype: int64

# %%
df.groupby('customer_name')['discount'].mean()
# Out:
# customer_name
# Aaron Bergman         0.110112
# Aaron Hawkins         0.160929
# Aaron Smayling        0.167667
# Adam Bellavance       0.131765
# Adam Hart             0.093238
#                         ...
# Xylona Preis          0.084754
# Yana Sorensen         0.070968
# Yoseph Carroll        0.070000
# Zuschuss Carroll      0.221318
# Zuschuss Donatelli    0.115778
# Name: discount, Length: 795, dtype: float64

# %%
df.groupby('order_date_year')['sales'].sum()
# Out:
# order_date_year
# 2011    4081206645114553142769126673382118541931591951...
# 2012    2,8221,2304174131,1886279162744521782452651032...
# 2013    1,6491,3587292,1901,36229924615524241785951151...
# 2014    6778463321571603021072031529954354138138404319...
# Name: sales, dtype: object

# %%
df.sales
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: object

# %%
df['sales'].unique()
# Out:
# array(['408', '120', '66', ..., '1,763', '1,821', '1,831'], dtype=object)

# %%
df['sales'] = df.sales.str.replace(',' , "").astype(int)

# %%
df['sales']
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: int32

# %%
df.groupby('order_date_year')['sales'].sum()
# Out:
# order_date_year
# 2011    2259511
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32

# %%
 # Assuming 'your_column' is the column you want to convert
df['your_column'] = pd.to_numeric(df['your_column'], errors='coerce').astype('Int64')

# %%
df['your_column'] = pd.to_numeric(df['your_column'], errors='coerce')

# %%
https://drive.google.com/file/d/1FRnbQqgK6S-mr9StNF5MurSaXhah9uoJ/view?usp=sharing


https://drive.google.com/file/d/11rPJXr-9VoeV2Pi0RSfVehw1tbQOAjLI/view?usp=sharing

https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true


https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true

1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
2 .Total working days for each agents 
3. Total query that you hvae taken 
4. total Feedback that you have received 
5. a agent name who have average rating between 3.5 to 4 
6 . Agent name who have rating lesss then 3.5 
7 . agent name who have rating more then 4.5 
8 . how many feedaback agents have received more then 4.5 average
9 . average weekly response time for each agent 
10 . average weekely resolution time for each agents 
11 . list of all agents name 
12 . percentage of chat on which they have received a feedback 
13 . Total contributation hour for each and every agents weekly basis 
14. total percentage of active hour for a month
